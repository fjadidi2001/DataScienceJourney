# %% [markdown]
# <a href="https://colab.research.google.com/github/fjadidi2001/DataScienceJourney/blob/master/RandomProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Random Project
#
#
# ![image.png](data:image/png;base64,...)
