# %% [markdown]
# <a href="https://colab.research.google.com/github/fjadidi2001/Artificial_Intelligence_Learning/blob/master/hWork1_soft_computing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# Define the fuzzy variables
level = ctrl.Antecedent(np.arange(0, 101, 1), 'level')
valve = ctrl.Consequent(np.arange(0, 101, 1), 'valve')

# Define the membership functions
level['low'] = fuzz.trimf(level.universe, [0, 25, 50])
level['okay'] = fuzz.trimf(level.universe, [25, 50, 75])
level['high'] = fuzz.trimf(level.universe, [50, 75, 100])

valve['closefast'] = fuzz.trimf(valve.universe, [0, 25, 50])
valve['nochange'] = fuzz.trimf(valve.universe, [25, 50, 75])
valve['openfast'] = fuzz.trimf(valve.universe, [50, 75, 100])

# Define the rules
rule1 = ctrl.Rule(level['okay'], valve['nochange'])
rule2 = ctrl.Rule(level['low'], valve['openfast'])
rule3 = ctrl.Rule(level['high'], valve['closefast'])

# Create the control system
control_system = ctrl.ControlSystem(rules=[rule1, rule2, rule3])

# Simulation
simulation = ctrl.ControlSystemSimulation(control_system)

# Set input level
simulation.input['level'] = 30

# Compute
simulation.compute()

# Print the output valve position
print(f"The valve position is {simulation.output['valve']:.2f}% open.")
# Out:
# The valve position is 68.97% open.

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# Define the fuzzy variables
level = ctrl.Antecedent(np.arange(0, 101, 1), 'level')
valve = ctrl.Consequent(np.arange(0, 101, 1), 'valve')

# Define the membership functions
level['low'] = fuzz.trimf(level.universe, [0, 25, 50])
level['okay'] = fuzz.trimf(level.universe, [25, 50, 75])
level['high'] = fuzz.trimf(level.universe, [50, 75, 100])

valve['closefast'] = fuzz.trimf(valve.universe, [0, 25, 50])
valve['nochange'] = fuzz.trimf(valve.universe, [25, 50, 75])
valve['openfast'] = fuzz.trimf(valve.universe, [50, 75, 100])

# Define the rules using the Mamdani method
rule1 = ctrl.Rule(level['okay'], valve['nochange'])
rule2 = ctrl.Rule(level['low'], valve['openfast'])
rule3 = ctrl.Rule(level['high'], valve['closefast'])

# Create the control system using the specified method settings
fis_ctrl = ctrl.ControlSystem(rules=[rule1, rule2, rule3],
                              aggregation_method=np.fmax,
                              aggregation_functions=np.fmax,
                              activation_func=np.fmin,
                              accumulation_func=np.fmax)

# Simulation
simulation = ctrl.ControlSystemSimulation(fis_ctrl)

# Set input level
simulation.input['level'] = 30

# Compute
simulation.compute()

# Print the output valve position
print(f"The valve position is {simulation.output['valve']:.2f}% open.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-bab7a42d7c16> in <cell line: 24>()
#      22
#      23 # Create the control system using the specified method settings
# ---> 24 fis_ctrl = ctrl.ControlSystem(rules=[rule1, rule2, rule3],
#      25                               aggregation_method=np.fmax,
#      26                               aggregation_functions=np.fmax,
#
# TypeError: ControlSystem.__init__() got an unexpected keyword argument 'aggregation_method'

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# Define the fuzzy variables
level = ctrl.Antecedent(np.arange(0, 101, 1), 'level')
valve = ctrl.Consequent(np.arange(0, 101, 1), 'valve')

# Define the membership functions
level['low'] = fuzz.trimf(level.universe, [0, 25, 50])
level['okay'] = fuzz.trimf(level.universe, [25, 50, 75])
level['high'] = fuzz.trimf(level.universe, [50, 75, 100])

valve['closefast'] = fuzz.trimf(valve.universe, [0, 25, 50])
valve['nochange'] = fuzz.trimf(valve.universe, [25, 50, 75])
valve['openfast'] = fuzz.trimf(valve.universe, [50, 75, 100])

# Define the rules using the Mamdani method
rule1 = ctrl.Rule(level['okay'], valve['nochange'])
rule2 = ctrl.Rule(level['low'], valve['openfast'])
rule3 = ctrl.Rule(level['high'], valve['closefast'])

# Create the control system using the Mamdani inference method
fis_ctrl = ctrl.FuzzyControlSystem([rule1, rule2, rule3], aggregation=np.fmax, defuzzify_method='centroid')

# Simulation
simulation = ctrl.ControlSystemSimulation(fis_ctrl)

# Set input level
simulation.input['level'] = 30

# Compute
simulation.compute()

# Print the output valve position
print(f"The valve position is {simulation.output['valve']:.2f}% open.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-2b7e8e6470ad> in <cell line: 24>()
#      22
#      23 # Create the control system using the Mamdani inference method
# ---> 24 fis_ctrl = ctrl.FuzzyControlSystem([rule1, rule2, rule3], aggregation=np.fmax, defuzzify_method='centroid')
#      25
#      26 # Simulation
#
# AttributeError: module 'skfuzzy.control' has no attribute 'FuzzyControlSystem'

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# New Antecedent/Consequent objects hold universe variables and membership functions
level = ctrl.Antecedent(np.arange(0, 101, 1), 'level')
valve = ctrl.Consequent(np.arange(0, 101, 1), 'valve')

# Define the membership functions using the names provided
level['low'] = fuzz.trimf(level.universe, [0, 25, 50])
level['okay'] = fuzz.trimf(level.universe, [25, 50, 75])
level['high'] = fuzz.trimf(level.universe, [50, 75, 100])

valve['closefast'] = fuzz.trimf(valve.universe, [0, 25, 50])
valve['nochange'] = fuzz.trimf(valve.universe, [25, 50, 75])
valve['openfast'] = fuzz.trimf(valve.universe, [50, 75, 100])

# Define the rules using the Mamdani implication method
rule1 = ctrl.Rule(antecedent=level['okay'], consequent=valve['nochange'])
rule2 = ctrl.Rule(antecedent=level['low'], consequent=valve['openfast'])
rule3 = ctrl.Rule(antecedent=level['high'], consequent=valve['closefast'])

# Create a ControlSystem using the specified properties
fis_ctrl = ctrl.ControlSystem(rules=[rule1, rule2, rule3], aggregation_method=np.fmax, aggregation_functions=np.fmax, activation_func=np.fmin, accumulation_func=np.fmax)

# Create a simulation
fis_simulation = ctrl.ControlSystemSimulation(fis_ctrl)

# Set the input level
fis_simulation.input['level'] = 30

# Compute
fis_simulation.compute()

# Print the output valve position
print(f"The valve position is {fis_simulation.output['valve']:.2f}% open.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-95aa86e6c1eb> in <cell line: 24>()
#      22
#      23 # Create a ControlSystem using the specified properties
# ---> 24 fis_ctrl = ctrl.ControlSystem(rules=[rule1, rule2, rule3], aggregation_method=np.fmax, aggregation_functions=np.fmax, activation_func=np.fmin, accumulation_func=np.fmax)
#      25
#      26 # Create a simulation
#
# TypeError: ControlSystem.__init__() got an unexpected keyword argument 'aggregation_method'

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# Define universe variables
level = np.arange(0, 101, 1)
valve = np.arange(0, 101, 1)

# Generate fuzzy membership functions
level_low = fuzz.trimf(level, [0, 0, 50])
level_okay = fuzz.trimf(level, [25, 50, 75])
level_high = fuzz.trimf(level, [50, 100, 100])

valve_closefast = fuzz.trimf(valve, [0, 0, 50])
valve_nochange = fuzz.trimf(valve, [25, 50, 75])
valve_openfast = fuzz.trimf(valve, [50, 100, 100])

# Visualize these universes and membership functions
# If you want to visualize, uncomment the following lines
import matplotlib.pyplot as plt
fig, (ax0, ax1) = plt.subplots(nrows=2, figsize=(8, 9))
ax0.plot(level, level_low, 'b', linewidth=1.5, label='Low')
ax0.plot(level, level_okay, 'g', linewidth=1.5, label='Okay')
ax0.plot(level, level_high, 'r', linewidth=1.5, label='High')
ax0.set_title('Water Tank Level')
ax0.legend()
ax1.plot(valve, valve_closefast, 'b', linewidth=1.5, label='Close Fast')
ax1.plot(valve, valve_nochange, 'g', linewidth=1.5, label='No Change')
ax1.plot(valve, valve_openfast, 'r', linewidth=1.5, label='Open Fast')
ax1.set_title('Valve Opening')
ax1.legend()
plt.show()

# Fuzzy rules
rule1 = ctrl.Rule(level_okay, valve_nochange)
rule2 = ctrl.Rule(level_low, valve_openfast)
rule3 = ctrl.Rule(level_high, valve_closefast)

# Control System Creation and Simulation
valve_ctrl = ctrl.ControlSystem([rule1, rule2, rule3])
valve_simulation = ctrl.ControlSystemSimulation(valve_ctrl)

# Input
valve_simulation.input['level'] = 30

# Compute the simulation
valve_simulation.compute()

# Output
output_valve = valve_simulation.output['valve']
print(f"The output valve value is {output_valve}")

# Defuzzification
output_valve_defuzz = fuzz.defuzz(valve, valve_simulation.output['valve'], 'centroid')
print(f"The defuzzified output valve value is {output_valve_defuzz}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-5cefd0fd0e4d> in <cell line: 35>()
#      33
#      34 # Fuzzy rules
# ---> 35 rule1 = ctrl.Rule(level_okay, valve_nochange)
#      36 rule2 = ctrl.Rule(level_low, valve_openfast)
#      37 rule3 = ctrl.Rule(level_high, valve_closefast)
#
# /usr/local/lib/python3.10/dist-packages/skfuzzy/control/rule.py in __init__(self, antecedent, consequent, label, and_func, or_func)
#      87         self._consequent = None
#      88         if antecedent is not None:
# ---> 89             self.antecedent = antecedent
#      90         if consequent is not None:
#      91             self.consequent = consequent
#
# /usr/local/lib/python3.10/dist-packages/skfuzzy/control/rule.py in antecedent(self, value)
#     165         """
#     166         if not isinstance(value, TermPrimitive):
# --> 167             raise ValueError("Unexpected antecedent type")
#     168         # Should be either Term or TermAggregate
#     169         self._antecedent = value
#
# ValueError: Unexpected antecedent type

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# New Antecedent/Consequent objects
level = ctrl.Antecedent(np.arange(0, 101, 1), 'level')
valve = ctrl.Consequent(np.arange(0, 101, 1), 'valve')

# Generate fuzzy membership functions
level['low'] = fuzz.trimf(level.universe, [0, 0, 50])
level['okay'] = fuzz.trimf(level.universe, [25, 50, 75])
level['high'] = fuzz.trimf(level.universe, [50, 100, 100])

valve['closefast'] = fuzz.trimf(valve.universe, [0, 0, 50])
valve['nochange'] = fuzz.trimf(valve.universe, [25, 50, 75])
valve['openfast'] = fuzz.trimf(valve.universe, [50, 100, 100])

# Fuzzy rules
rule1 = ctrl.Rule(level['okay'], valve['nochange'])
rule2 = ctrl.Rule(level['low'], valve['openfast'])
rule3 = ctrl.Rule(level['high'], valve['closefast'])

# Control System Creation and Simulation
valve_ctrl = ctrl.ControlSystem(rules=[rule1, rule2, rule3])
valve_simulation = ctrl.ControlSystemSimulation(valve_ctrl)

# Input
valve_simulation.input['level'] = 30

# Compute the simulation
valve_simulation.compute()

# Output
output_valve = valve_simulation.output['valve']
print(f"The output valve value is {output_valve}")

# Defuzzification
output_valve_defuzz = fuzz.defuzz(valve.universe, output_valve, 'centroid')
print(f"The defuzzified output valve value is {output_valve_defuzz}")
# Out:
# The output valve value is 69.80620155038763
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-18-280fa049827b> in <cell line: 38>()
#      36
#      37 # Defuzzification
# ---> 38 output_valve_defuzz = fuzz.defuzz(valve.universe, output_valve, 'centroid')
#      39 print(f"The defuzzified output valve value is {output_valve_defuzz}")
#
# /usr/local/lib/python3.10/dist-packages/skfuzzy/defuzzify/defuzz.py in defuzz(x, mfx, mode)
#     241     mfx = mfx.ravel()
#     242     n = len(x)
# --> 243     assert n == len(mfx), 'Length of x and fuzzy membership function must be \
#     244                           identical.'
#     245
#
# AssertionError: Length of x and fuzzy membership function must be                           identical.

# %%
# !pip install scikit-fuzzy
# Out:
# Requirement already satisfied: scikit-fuzzy in /usr/local/lib/python3.10/dist-packages (0.4.2)
# Requirement already satisfied: numpy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-fuzzy) (1.23.5)
# Requirement already satisfied: scipy>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from scikit-fuzzy) (1.11.3)
# Requirement already satisfied: networkx>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from scikit-fuzzy) (3.2)

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# New Antecedent/Consequent objects
level = ctrl.Antecedent(np.arange(-1, 1.01, 0.01), 'level')
valve = ctrl.Consequent(np.arange(0, 1.01, 0.01), 'valve')

# Generate fuzzy membership functions
level['low'] = fuzz.para membership function for levels is period of -1, -0.8, 0.6, 0.4, 0.2, 0, 0.2, 0.4, 0.6, 0.8bolic2mf(level.universe, -0.6, 0)
level['okay'] = fuzz.trimf(level.universe, [-0.4, 0, 0.4])
level['high'] = fuzz.parabolic2mf(level.universe, 0.6, 0)

valve['closefast'] = fuzz.trimf(valve.universe, [0, 0, 0.5])
valve['nochange'] = fuzz.trimf(valve.universe, [0, 0.5, 1])
valve['openfast'] = fuzz.trimf(valve.universe, [0.5, 1, 1])

# Fuzzy rules
rule1 = ctrl.Rule(level['okay'], valve['nochange'])
rule2 = ctrl.Rule(level['low'], valve['openfast'])
rule3 = ctrl.Rule(level['high'], valve['closefast'])

# Control System Creation and Simulation
valve_ctrl = ctrl.ControlSystem(rules=[rule1, rule2, rule3])
valve_simulation = ctrl.ControlSystemSimulation(valve_ctrl)

# Input
valve_simulation.input['level'] = 0.3

# Compute the simulation
valve_simulation.compute()

# Output
output_valve = valve_simulation.output['valve']
print(f"The output valve value is {output_valve}")

# Defuzzification
output_valve_defuzz = fuzz.defuzz(valve.universe, output_valve, 'centroid')
print(f"The defuzzified output valve value is {output_valve_defuzz}")
# Out:
#   File "<ipython-input-21-ad1d96c70711>", line 10
#     level['low'] = fuzz.para membership function for levels is period of -1, -0.8, 0.6, 0.4, 0.2, 0, 0.2, 0.4, 0.6, 0.8bolic2mf(level.universe, -0.6, 0)
#                                                                                                                       ^
# SyntaxError: invalid decimal literal

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# New Antecedent/Consequent objects
level = ctrl.Antecedent(np.arange(-1, 1.01, 0.01), 'level')
valve = ctrl.Consequent(np.arange(0, 1.01, 0.01), 'valve')

# Generate fuzzy membership functions
level['low'] = fuzz.trimf(level.universe, [-1, -0.8, -0.6])
level['okay'] = fuzz.trimf(level.universe, [-0.4, 0, 0.4])
level['high'] = fuzz.trimf(level.universe, [0.6, 0.8, 1])

valve['closefast'] = fuzz.trimf(valve.universe, [0, 0, 0.5])
valve['nochange'] = fuzz.trimf(valve.universe, [0, 0.5, 1])
valve['openfast'] = fuzz.trimf(valve.universe, [0.5, 1, 1])

# Fuzzy rules
rule1 = ctrl.Rule(level['okay'], valve['nochange'])
rule2 = ctrl.Rule(level['low'], valve['openfast'])
rule3 = ctrl.Rule(level['high'], valve['closefast'])

# Control System Creation and Simulation
valve_ctrl = ctrl.ControlSystem([rule1, rule2, rule3])
valve_simulation = ctrl.ControlSystemSimulation(valve_ctrl)

# Input
valve_simulation.input['level'] = 0.3

# Compute the simulation
valve_simulation.compute()

# Output
output_valve = valve_simulation.output['valve']
print(f"The output valve value is {output_valve}")

# Defuzzification
output_valve_defuzz = fuzz.defuzz(valve.universe, output_valve, 'centroid')
print(f"The defuzzified output valve value is {output_valve_defuzz}")
# Out:
# The output valve value is 0.5000000000000003
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-24-a18145930f49> in <cell line: 38>()
#      36
#      37 # Defuzzification
# ---> 38 output_valve_defuzz = fuzz.defuzz(valve.universe, output_valve, 'centroid')
#      39 print(f"The defuzzified output valve value is {output_valve_defuzz}")
#
# /usr/local/lib/python3.10/dist-packages/skfuzzy/defuzzify/defuzz.py in defuzz(x, mfx, mode)
#     241     mfx = mfx.ravel()
#     242     n = len(x)
# --> 243     assert n == len(mfx), 'Length of x and fuzzy membership function must be \
#     244                           identical.'
#     245
#
# AssertionError: Length of x and fuzzy membership function must be                           identical.

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# New Antecedent/Consequent objects
level = ctrl.Antecedent(np.arange(-1, 1.01, 0.01), 'level')
valve = ctrl.Consequent(np.arange(0, 1.01, 0.01), 'valve')

# Generate fuzzy membership functions
level['low'] = fuzz.trimf(level.universe, [-1, -0.8, 0.6])
level['okay'] = fuzz.trimf(level.universe, [-0.4, 0, 0.4])
level['high'] = fuzz.trimf(level.universe, [0.6, 0.8, 1])

valve['closefast'] = fuzz.trimf(valve.universe, [0, 0, 0.5])
valve['nochange'] = fuzz.trimf(valve.universe, [0, 0.5, 1])
valve['openfast'] = fuzz.trimf(valve.universe, [0.5, 1, 1])

# Fuzzy rules
rule1 = ctrl.Rule(level['okay'], valve['nochange'])
rule2 = ctrl.Rule(level['low'], valve['openfast'])
rule3 = ctrl.Rule(level['high'], valve['closefast'])

# Control System Creation and Simulation
valve_ctrl = ctrl.ControlSystem([rule1, rule2, rule3])
valve_simulation = ctrl.ControlSystemSimulation(valve_ctrl)

# Input
valve_simulation.input['level'] = 0.3

# Compute the simulation
valve_simulation.compute()

# Output
output_valve = valve_simulation.output['valve']
print(f"The output valve value is {output_valve}")

# Defuzzification
output_valve_defuzz = fuzz.defuzz(valve.universe, output_valve, 'centroid')
print(f"The defuzzified output valve value is {output_valve_defuzz}")
# Out:
# The output valve value is 0.5231828757561661
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-25-ffec742506e3> in <cell line: 38>()
#      36
#      37 # Defuzzification
# ---> 38 output_valve_defuzz = fuzz.defuzz(valve.universe, output_valve, 'centroid')
#      39 print(f"The defuzzified output valve value is {output_valve_defuzz}")
#
# /usr/local/lib/python3.10/dist-packages/skfuzzy/defuzzify/defuzz.py in defuzz(x, mfx, mode)
#     241     mfx = mfx.ravel()
#     242     n = len(x)
# --> 243     assert n == len(mfx), 'Length of x and fuzzy membership function must be \
#     244                           identical.'
#     245
#
# AssertionError: Length of x and fuzzy membership function must be                           identical.

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
import matplotlib.pyplot as plt

# New Antecedent/Consequent objects
level = ctrl.Antecedent(np.arange(-1, 1.01, 0.01), 'level')
valve = ctrl.Consequent(np.arange(0, 1.01, 0.01), 'valve')

# Generate fuzzy membership functions
level['low'] = fuzz.trimf(level.universe, [-1, -0.8, 0.6])
level['okay'] = fuzz.trimf(level.universe, [-0.4, 0, 0.4])
level['high'] = fuzz.trimf(level.universe, [0.6, 0.8, 1])

valve['closefast'] = fuzz.trimf(valve.universe, [0, 0, 0.5])
valve['nochange'] = fuzz.trimf(valve.universe, [0, 0.5, 1])
valve['openfast'] = fuzz.trimf(valve.universe, [0.5, 1, 1])

# Visualize membership functions
fig, (ax0, ax1) = plt.subplots(nrows=2, figsize=(8, 6))

ax0.plot(level.universe, fuzz.trimf(level.universe, [-1, -0.8, 0.6]), 'b', linewidth=1.5, label='Low')
ax0.plot(level.universe, fuzz.trimf(level.universe, [-0.4, 0, 0.4]), 'g', linewidth=1.5, label='Okay')
ax0.plot(level.universe, fuzz.trimf(level.universe, [0.6, 0.8, 1]), 'r', linewidth=1.5, label='High')
ax0.set_title('Membership Function for Level')
ax0.legend()

ax1.plot(valve.universe, fuzz.trimf(valve.universe, [0, 0, 0.5]), 'b', linewidth=1.5, label='Close Fast')
ax1.plot(valve.universe, fuzz.trimf(valve.universe, [0, 0.5, 1]), 'g', linewidth=1.5, label='No Change')
ax1.plot(valve.universe, fuzz.trimf(valve.universe, [0.5, 1, 1]), 'r', linewidth=1.5, label='Open Fast')
ax1.set_title('Membership Function for Valve')
ax1.legend()

# Show plots
plt.tight_layout()
plt.show()

# Fuzzy rules
rule1 = ctrl.Rule(level['okay'], valve['nochange'])
rule2 = ctrl.Rule(level['low'], valve['openfast'])
rule3 = ctrl.Rule(level['high'], valve['closefast'])

# Control System Creation and Simulation
valve_ctrl = ctrl.ControlSystem([rule1, rule2, rule3])
valve_simulation = ctrl.ControlSystemSimulation(valve_ctrl)

# Input
valve_simulation.input['level'] = 0.3

# Compute the simulation
valve_simulation.compute()

# Output
output_valve = valve_simulation.output['valve']
print(f"The output valve value is {output_valve}")

# Defuzzification
output_valve_defuzz = fuzz.defuzz(valve.universe, output_valve, 'centroid')
print(f"The defuzzified output valve value is {output_valve_defuzz}")
# Out:
# The output valve value is 0.5231828757561661
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-26-ab80552d4eeb> in <cell line: 58>()
#      56
#      57 # Defuzzification
# ---> 58 output_valve_defuzz = fuzz.defuzz(valve.universe, output_valve, 'centroid')
#      59 print(f"The defuzzified output valve value is {output_valve_defuzz}")
#
# /usr/local/lib/python3.10/dist-packages/skfuzzy/defuzzify/defuzz.py in defuzz(x, mfx, mode)
#     241     mfx = mfx.ravel()
#     242     n = len(x)
# --> 243     assert n == len(mfx), 'Length of x and fuzzy membership function must be \
#     244                           identical.'
#     245
#
# AssertionError: Length of x and fuzzy membership function must be                           identical.

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# Define the input variables and their respective membership functions
level = ctrl.Antecedent(np.arange(-1, 1.1, 0.1), 'level')
level['high'] = fuzz.trimf(level.universe, [-1, -0.6, 0.6])
level['okay'] = fuzz.trimf(level.universe, [-0.4, 0, 0.4])
level['low'] = fuzz.trimf(level.universe, [-0.2, 0.8, 1])

# Define the output variable and its membership functions
valve = ctrl.Consequent(np.arange(0, 1.1, 0.1), 'valve')
valve['closefast'] = fuzz.trimf(valve.universe, [0, 0, 0.4])
valve['nochange'] = fuzz.trimf(valve.universe, [0.2, 0.5, 0.8])
valve['openfast'] = fuzz.trimf(valve.universe, [0.6, 1, 1])

# Define the fuzzy rules
rule1 = ctrl.Rule(level['okay'], valve['nochange'])
rule2 = ctrl.Rule(level['low'], valve['openfast'])
rule3 = ctrl.Rule(level['high'], valve['closefast'])

# Create the control system
fis_ctrl = ctrl.ControlSystem([rule1, rule2, rule3])

# Create the simulation
fis_sim = ctrl.ControlSystemSimulation(fis_ctrl)

# Set the input value
fis_sim.input['level'] = 0.5

# Evaluate the fuzzy system
fis_sim.compute()

# Print the output value
print("Output value for the fuzzy system:", fis_sim.output['valve'])
# Out:
# Output value for the fuzzy system: 0.7580466834011367

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
import matplotlib.pyplot as plt

# Define the input variables and their respective membership functions
level = ctrl.Antecedent(np.arange(-1, 1.1, 0.1), 'level')
level['high'] = fuzz.trimf(level.universe, [-1, -0.6, 0.6])
level['okay'] = fuzz.trimf(level.universe, [-0.4, 0, 0.4])
level['low'] = fuzz.trimf(level.universe, [-0.2, 0.8, 1])

# Define the output variable and its membership functions
valve = ctrl.Consequent(np.arange(0, 1.1, 0.1), 'valve')
valve['closefast'] = fuzz.trimf(valve.universe, [0, 0, 0.4])
valve['nochange'] = fuzz.trimf(valve.universe, [0.2, 0.5, 0.8])
valve['openfast'] = fuzz.trimf(valve.universe, [0.6, 1, 1])

# Define the fuzzy rules
rule1 = ctrl.Rule(level['okay'], valve['nochange'])
rule2 = ctrl.Rule(level['low'], valve['openfast'])
rule3 = ctrl.Rule(level['high'], valve['closefast'])

# Create the control system
fis_ctrl = ctrl.ControlSystem([rule1, rule2, rule3])

# Create the simulation
fis_sim = ctrl.ControlSystemSimulation(fis_ctrl)

# Visualize the membership functions
level.view()
valve.view()

# Set the input value
fis_sim.input['level'] = 0.5

# Evaluate the fuzzy system
fis_sim.compute()

# Visualize the aggregated output
aggregated = ctrl.fuzzy_and(fis_sim.output['valve'], valve.universe)
fig, ax0 = plt.subplots(figsize=(8, 3))
ax0.plot(valve.universe, aggregated, 'r', linewidth=1.5, label='Aggregated')

# Visualize the defuzzified output
val = fis_sim.output['valve']
ax0.fill_between(valve.universe, 0, aggregated, facecolor='r', alpha=0.2)
ax0.plot([val, val], [0, fuzz.interp_membership(valve.universe, aggregated, val)], 'k', linewidth=1.5, alpha=0.9)
ax0.set_title('Aggregated and Defuzzified Output')
ax0.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-26a7b10c25c3> in <cell line: 40>()
#      38
#      39 # Visualize the aggregated output
# ---> 40 aggregated = ctrl.fuzzy_and(fis_sim.output['valve'], valve.universe)
#      41 fig, ax0 = plt.subplots(figsize=(8, 3))
#      42 ax0.plot(valve.universe, aggregated, 'r', linewidth=1.5, label='Aggregated')
#
# AttributeError: module 'skfuzzy.control' has no attribute 'fuzzy_and'

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
import matplotlib.pyplot as plt

# Define the input variables and their respective membership functions
level = ctrl.Antecedent(np.arange(-1, 1.1, 0.1), 'level')
level['high'] = fuzz.trimf(level.universe, [-1, -0.6, 0.6])
level['okay'] = fuzz.trimf(level.universe, [-0.4, 0, 0.4])
level['low'] = fuzz.trimf(level.universe, [-0.2, 0.8, 1])

# Define the output variable and its membership functions
valve = ctrl.Consequent(np.arange(0, 1.1, 0.1), 'valve')
valve['closefast'] = fuzz.trimf(valve.universe, [0, 0, 0.4])
valve['nochange'] = fuzz.trimf(valve.universe, [0.2, 0.5, 0.8])
valve['openfast'] = fuzz.trimf(valve.universe, [0.6, 1, 1])

# Define the fuzzy rules
rule1 = ctrl.Rule(level['okay'], valve['nochange'])
rule2 = ctrl.Rule(level['low'], valve['openfast'])
rule3 = ctrl.Rule(level['high'], valve['closefast'])

# Create the control system
fis_ctrl = ctrl.ControlSystem([rule1, rule2, rule3])

# Create the simulation
fis_sim = ctrl.ControlSystemSimulation(fis_ctrl)

# Visualize the membership functions
level.view()
valve.view()

# Set the input value
fis_sim.input['level'] = 0.5

# Evaluate the fuzzy system
fis_sim.compute()

# Visualize the aggregated output
aggregated = ctrl.fuzzy_and(fis_sim.output['valve'], valve.universe)
fig, ax0 = plt.subplots(figsize=(8, 3))
ax0.plot(valve.universe, aggregated, 'r', linewidth=1.5, label='Aggregated')

# Visualize the defuzzified output
val = fis_sim.output['valve']
ax0.fill_between(valve.universe, 0, aggregated, facecolor='r', alpha=0.2)
ax0.plot([val, val], [0, fuzz.interp_membership(valve.universe, aggregated, val)], 'k', linewidth=1.5, alpha=0.9)
ax0.set_title('Aggregated and Defuzzified Output')
ax0.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-26a7b10c25c3> in <cell line: 40>()
#      38
#      39 # Visualize the aggregated output
# ---> 40 aggregated = ctrl.fuzzy_and(fis_sim.output['valve'], valve.universe)
#      41 fig, ax0 = plt.subplots(figsize=(8, 3))
#      42 ax0.plot(valve.universe, aggregated, 'r', linewidth=1.5, label='Aggregated')
#
# AttributeError: module 'skfuzzy.control' has no attribute 'fuzzy_and'

# %%
# !pip install scikit-fuzzy matplotlib
# Out:
# Requirement already satisfied: scikit-fuzzy in /usr/local/lib/python3.10/dist-packages (0.4.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: numpy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-fuzzy) (1.23.5)
# Requirement already satisfied: scipy>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from scikit-fuzzy) (1.11.3)
# Requirement already satisfied: networkx>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from scikit-fuzzy) (3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

# Generate universe variables
x_level = np.arange(-1, 1.01, 0.01)
x_valve = np.arange(0, 1.01, 0.01)

# Generate fuzzy membership functions
level_low = fuzz.trimf(x_level, [-1, -0.8, 0.6])
level_okay = fuzz.trimf(x_level, [-0.4, 0, 0.4])
level_high = fuzz.trimf(x_level, [0.6, 0.8, 1])

valve_closefast = fuzz.trimf(x_valve, [0, 0, 0.5])
valve_nochange = fuzz.trimf(x_valve, [0, 0.5, 1])
valve_openfast = fuzz.trimf(x_valve, [0.5, 1, 1])

# Visualize membership functions
plt.figure(figsize=(8, 6))

plt.plot(x_level, level_low, 'b', label='Low')
plt.plot(x_level, level_okay, 'g', label='Okay')
plt.plot(x_level, level_high, 'r', label='High')
plt.title('Membership Function for Level')
plt.legend()
plt.show()

plt.figure(figsize=(8, 6))
plt.plot(x_valve, valve_closefast, 'b', label='Close Fast')
plt.plot(x_valve, valve_nochange, 'g', label='No Change')
plt.plot(x_valve, valve_openfast, 'r', label='Open Fast')
plt.title('Membership Function for Valve')
plt.legend()
plt.show()

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
import matplotlib.pyplot as plt

# New Antecedent/Consequent objects
level = ctrl.Antecedent(np.arange(-1, 1.01, 0.01), 'level')
valve = ctrl.Consequent(np.arange(0, 1.01, 0.01), 'valve')

# Generate fuzzy membership functions
level['low'] = fuzz.trimf(level.universe, [-1, -0.8, 0.6])
level['okay'] = fuzz.trimf(level.universe, [-0.4, 0, 0.4])
level['high'] = fuzz.trimf(level.universe, [0.6, 0.8, 1])

valve['closefast'] = fuzz.trimf(valve.universe, [0, 0, 0.5])
valve['nochange'] = fuzz.trimf(valve.universe, [0, 0.5, 1])
valve['openfast'] = fuzz.trimf(valve.universe, [0.5, 1, 1])

# Visualize membership functions
fig, (ax0, ax1) = plt.subplots(nrows=2, figsize=(8, 6))

ax0.plot(level.universe, fuzz.trimf(level.universe, [-1, -0.8, 0.6]), 'b', linewidth=1.5, label='Low')
ax0.plot(level.universe, fuzz.trimf(level.universe, [-0.4, 0, 0.4]), 'g', linewidth=1.5, label='Okay')
ax0.plot(level.universe, fuzz.trimf(level.universe, [0.6, 0.8, 1]), 'r', linewidth=1.5, label='High')
ax0.set_title('Membership Function for Level')
ax0.legend()

ax1.plot(valve.universe, fuzz.trimf(valve.universe, [0, 0, 0.5]), 'b', linewidth=1.5, label='Close Fast')
ax1.plot(valve.universe, fuzz.trimf(valve.universe, [0, 0.5, 1]), 'g', linewidth=1.5, label='No Change')
ax1.plot(valve.universe, fuzz.trimf(valve.universe, [0.5, 1, 1]), 'r', linewidth=1.5, label='Open Fast')
ax1.set_title('Membership Function for Valve')
ax1.legend()

# Show plots
plt.tight_layout()
plt.show()

# Fuzzy rules
rule1 = ctrl.Rule(level['okay'], valve['nochange'])
rule2 = ctrl.Rule(level['low'], valve['openfast'])
rule3 = ctrl.Rule(level['high'], valve['closefast'])

# Control System Creation and Simulation
valve_ctrl = ctrl.ControlSystem([rule1, rule2, rule3])
valve_simulation = ctrl.ControlSystemSimulation(valve_ctrl)

# Input
valve_simulation.input['level'] = 0.3

# Compute the simulation
valve_simulation.compute()

# Output
output_valve = valve_simulation.output['valve']
print(f"The output valve value is {output_valve}")

# Defuzzification
output_valve_defuzz = fuzz.defuzz(valve.universe, output_valve, 'centroid')
print(f"The defuzzified output valve value is {output_valve_defuzz}")
# Out:
# The output valve value is 0.5231828757561661
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-33-ab80552d4eeb> in <cell line: 58>()
#      56
#      57 # Defuzzification
# ---> 58 output_valve_defuzz = fuzz.defuzz(valve.universe, output_valve, 'centroid')
#      59 print(f"The defuzzified output valve value is {output_valve_defuzz}")
#
# /usr/local/lib/python3.10/dist-packages/skfuzzy/defuzzify/defuzz.py in defuzz(x, mfx, mode)
#     241     mfx = mfx.ravel()
#     242     n = len(x)
# --> 243     assert n == len(mfx), 'Length of x and fuzzy membership function must be \
#     244                           identical.'
#     245
#
# AssertionError: Length of x and fuzzy membership function must be                           identical.

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# New Antecedent/Consequent objects
level = ctrl.Antecedent(np.arange(-1, 1.01, 0.01), 'level')
valve = ctrl.Consequent(np.arange(0, 1.01, 0.01), 'valve')

# Generate fuzzy membership functions
level['low'] = fuzz.trimf(level.universe, [-1, -0.8, -0.6])
level['okay'] = fuzz.trimf(level.universe, [-0.4, 0, 0.4])
level['high'] = fuzz.trimf(level.universe, [0.6, 0.8, 1])

valve['closefast'] = fuzz.trimf(valve.universe, [0, 0, 0.5])
valve['nochange'] = fuzz.trimf(valve.universe, [0, 0.5, 1])
valve['openfast'] = fuzz.trimf(valve.universe, [0.5, 1, 1])

# Fuzzy rules
rule1 = ctrl.Rule(level['okay'], valve['nochange'])
rule2 = ctrl.Rule(level['low'], valve['openfast'])
rule3 = ctrl.Rule(level['high'], valve['closefast'])

# Control System Creation and Simulation
valve_ctrl = ctrl.ControlSystem([rule1, rule2, rule3])
valve_simulation = ctrl.ControlSystemSimulation(valve_ctrl)

# Input
valve_simulation.input['level'] = 0.3

# Compute the simulation
valve_simulation.compute()

# Output
output_valve = valve_simulation.output['valve']
print(f"The output valve value is {output_valve}")

# Defuzzification
output_valve_defuzz = fuzz.defuzz(valve.universe, output_valve, 'centroid')
print(f"The defuzzified output valve value is {output_valve_defuzz}")
# Out:
# The output valve value is 0.5000000000000003
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-34-a18145930f49> in <cell line: 38>()
#      36
#      37 # Defuzzification
# ---> 38 output_valve_defuzz = fuzz.defuzz(valve.universe, output_valve, 'centroid')
#      39 print(f"The defuzzified output valve value is {output_valve_defuzz}")
#
# /usr/local/lib/python3.10/dist-packages/skfuzzy/defuzzify/defuzz.py in defuzz(x, mfx, mode)
#     241     mfx = mfx.ravel()
#     242     n = len(x)
# --> 243     assert n == len(mfx), 'Length of x and fuzzy membership function must be \
#     244                           identical.'
#     245
#
# AssertionError: Length of x and fuzzy membership function must be                           identical.

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# New Antecedent/Consequent objects
level = ctrl.Antecedent(np.arange(-1, 1.01, 0.01), 'level')
valve = ctrl.Consequent(np.arange(0, 1.01, 0.01), 'valve')

# Generate fuzzy membership functions
level['low'] = fuzz.para membership function for levels is period of -1, -0.8, 0.6, 0.4, 0.2, 0, 0.2, 0.4, 0.6, 0.8bolic2mf(level.universe, -0.6, 0)
level['okay'] = fuzz.trimf(level.universe, [-0.4, 0, 0.4])
level['high'] = fuzz.parabolic2mf(level.universe, 0.6, 0)

valve['closefast'] = fuzz.trimf(valve.universe, [0, 0, 0.5])
valve['nochange'] = fuzz.trimf(valve.universe, [0, 0.5, 1])
valve['openfast'] = fuzz.trimf(valve.universe, [0.5, 1, 1])

# Fuzzy rules
rule1 = ctrl.Rule(level['okay'], valve['nochange'])
rule2 = ctrl.Rule(level['low'], valve['openfast'])
rule3 = ctrl.Rule(level['high'], valve['closefast'])

# Control System Creation and Simulation
valve_ctrl = ctrl.ControlSystem(rules=[rule1, rule2, rule3])
valve_simulation = ctrl.ControlSystemSimulation(valve_ctrl)

# Input
valve_simulation.input['level'] = 0.3

# Compute the simulation
valve_simulation.compute()

# Output
output_valve = valve_simulation.output['valve']
print(f"The output valve value is {output_valve}")

# Defuzzification
output_valve_defuzz = fuzz.defuzz(valve.universe, output_valve, 'centroid')
print(f"The defuzzified output valve value is {output_valve_defuzz}")
# Out:
#   File "<ipython-input-35-ad1d96c70711>", line 10
#     level['low'] = fuzz.para membership function for levels is period of -1, -0.8, 0.6, 0.4, 0.2, 0, 0.2, 0.4, 0.6, 0.8bolic2mf(level.universe, -0.6, 0)
#                                                                                                                       ^
# SyntaxError: invalid decimal literal

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# New Antecedent/Consequent objects
level = ctrl.Antecedent(np.arange(-1, 1.01, 0.01), 'level')
valve = ctrl.Consequent(np.arange(0, 1.01, 0.01), 'valve')

# Generate fuzzy membership functions
level['low'] = fuzz.parabola2mf(level.universe, -0.6, 0)
level['okay'] = fuzz.trimf(level.universe, [-0.4, 0, 0.4])
level['high'] = fuzz.parabola2mf(level.universe, 0.6, 0)

valve['closefast'] = fuzz.trimf(valve.universe, [0, 0, 0.5])
valve['nochange'] = fuzz.trimf(valve.universe, [0, 0.5, 1])
valve['openfast'] = fuzz.trimf(valve.universe, [0.5, 1, 1])

# Fuzzy rules
rule1 = ctrl.Rule(level['okay'], valve['nochange'])
rule2 = ctrl.Rule(level['low'], valve['openfast'])
rule3 = ctrl.Rule(level['high'], valve['closefast'])

# Control System Creation and Simulation
valve_ctrl = ctrl.ControlSystem([rule1, rule2, rule3])
valve_simulation = ctrl.ControlSystemSimulation(valve_ctrl)

# Input
valve_simulation.input['level'] = 0.3

# Compute the simulation
valve_simulation.compute()

# Output
output_valve = valve_simulation.output['valve']
print(f"The output valve value is {output_valve}")

# Defuzzification
output_valve_defuzz = fuzz.defuzz(valve.universe, output_valve, 'centroid')
print(f"The defuzzified output valve value is {output_valve_defuzz}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-ec5c6b48ded5> in <cell line: 10>()
#       8
#       9 # Generate fuzzy membership functions
# ---> 10 level['low'] = fuzz.parabola2mf(level.universe, -0.6, 0)
#      11 level['okay'] = fuzz.trimf(level.universe, [-0.4, 0, 0.4])
#      12 level['high'] = fuzz.parabola2mf(level.universe, 0.6, 0)
#
# AttributeError: module 'skfuzzy' has no attribute 'parabola2mf'

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# New Antecedent/Consequent objects
level = ctrl.Antecedent(np.arange(-1, 1.01, 0.01), 'level')
valve = ctrl.Consequent(np.arange(0, 1.01, 0.01), 'valve')

# Generate fuzzy membership functions
level['low'] = fuzz.pimf(level.universe, -0.6, -0.6, -0.4, -0.4)
level['okay'] = fuzz.trimf(level.universe, [-0.4, 0, 0.4])
level['high'] = fuzz.pimf(level.universe, 0.4, 0.4, 0.6, 0.6)

valve['closefast'] = fuzz.trimf(valve.universe, [0, 0, 0.5])
valve['nochange'] = fuzz.trimf(valve.universe, [0, 0.5, 1])
valve['openfast'] = fuzz.trimf(valve.universe, [0.5, 1, 1])

# Fuzzy rules
rule1 = ctrl.Rule(level['okay'], valve['nochange'])
rule2 = ctrl.Rule(level['low'], valve['openfast'])
rule3 = ctrl.Rule(level['high'], valve['closefast'])

# Control System Creation and Simulation
valve_ctrl = ctrl.ControlSystem([rule1, rule2, rule3])
valve_simulation = ctrl.ControlSystemSimulation(valve_ctrl)

# Input
valve_simulation.input['level'] = 0.3

# Compute the simulation
valve_simulation.compute()

# Output
output_valve = valve_simulation.output['valve']
print(f"The output valve value is {output_valve}")

# Defuzzification
output_valve_defuzz = fuzz.defuzz(valve.universe, output_valve, 'centroid')
print(f"The defuzzified output valve value is {output_valve_defuzz}")
# Out:
# The output valve value is 0.5000000000000003
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-37-cba79238bb91> in <cell line: 38>()
#      36
#      37 # Defuzzification
# ---> 38 output_valve_defuzz = fuzz.defuzz(valve.universe, output_valve, 'centroid')
#      39 print(f"The defuzzified output valve value is {output_valve_defuzz}")
#
# /usr/local/lib/python3.10/dist-packages/skfuzzy/defuzzify/defuzz.py in defuzz(x, mfx, mode)
#     241     mfx = mfx.ravel()
#     242     n = len(x)
# --> 243     assert n == len(mfx), 'Length of x and fuzzy membership function must be \
#     244                           identical.'
#     245
#
# AssertionError: Length of x and fuzzy membership function must be                           identical.

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# New Antecedent/Consequent objects
level = ctrl.Antecedent(np.arange(-1, 1.01, 0.01), 'level')
valve = ctrl.Consequent(np.arange(0, 1.01, 0.01), 'valve')

# Generate fuzzy membership functions
level['low'] = fuzz.pimf(level.universe, -0.6, -0.6, -0.4, -0.4)
level['okay'] = fuzz.trimf(level.universe, [-0.4, 0, 0.4])
level['high'] = fuzz.pimf(level.universe, 0.4, 0.4, 0.6, 0.6)

valve['closefast'] = fuzz.trimf(valve.universe, [0, 0, 0.5])
valve['nochange'] = fuzz.trimf(valve.universe, [0, 0.5, 1])
valve['openfast'] = fuzz.trimf(valve.universe, [0.5, 1, 1])

# Fuzzy rules
rule1 = ctrl.Rule(level['okay'], valve['nochange'])
rule2 = ctrl.Rule(level['low'], valve['openfast'])
rule3 = ctrl.Rule(level['high'], valve['closefast'])

# Control System Creation and Simulation
valve_ctrl = ctrl.ControlSystem([rule1, rule2, rule3])
valve_simulation = ctrl.ControlSystemSimulation(valve_ctrl)

# Input
valve_simulation.input['level'] = 0.3

# Compute the simulation
valve_simulation.compute()

# Output
output_valve = valve_simulation.output['valve']
print(f"The output valve value is {output_valve}")
# Out:
# The output valve value is 0.5000000000000003

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
import matplotlib.pyplot as plt

# Define the input variables and their respective membership functions
level = ctrl.Antecedent(np.arange(-1, 1.1, 0.1), 'level')
level['high'] = fuzz.trimf(level.universe, [-1, -0.6, 0.6])
level['okay'] = fuzz.trimf(level.universe, [-0.4, 0, 0.4])
level['low'] = fuzz.trimf(level.universe, [-0.2, 0.8, 1])

# Define the output variable and its membership functions
valve = ctrl.Consequent(np.arange(0, 1.1, 0.1), 'valve')
valve['closefast'] = fuzz.trimf(valve.universe, [0, 0, 0.4])
valve['nochange'] = fuzz.trimf(valve.universe, [0.2, 0.5, 0.8])
valve['openfast'] = fuzz.trimf(valve.universe, [0.6, 1, 1])

# Define the fuzzy rules
rule1 = ctrl.Rule(level['okay'], valve['nochange'])
rule2 = ctrl.Rule(level['low'], valve['openfast'])
rule3 = ctrl.Rule(level['high'], valve['closefast'])

# Create the control system
fis_ctrl = ctrl.ControlSystem([rule1, rule2, rule3])

# Create the simulation
fis_sim = ctrl.ControlSystemSimulation(fis_ctrl)

# Visualize the membership functions
level.view()
valve.view()

# Set the input value
fis_sim.input['level'] = 0.5

# Evaluate the fuzzy system
fis_sim.compute()

# Get the membership values
agg_valve = np.fmin(fis_sim.output['valve'], valve.terms['nochange'].mf)
fig, ax0 = plt.subplots(figsize=(8, 3))
ax0.plot(valve.universe, valve.terms['nochange'].mf, 'g', linewidth=1.5, label='Membership Function')

# Visualize the aggregated output
ax0.fill_between(valve.universe, 0, agg_valve, facecolor='green', alpha=0.7)
ax0.set_title('Aggregated Output')

# Defuzzify and show the crisp output
defuzz_val = ctrl.defuzz(valve.universe, agg_valve, 'centroid')
ax0.plot([defuzz_val, defuzz_val], [0, 1], 'r', linewidth=1.5, label='Defuzzified Output')
ax0.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-36576540befe> in <cell line: 49>()
#      47
#      48 # Defuzzify and show the crisp output
# ---> 49 defuzz_val = ctrl.defuzz(valve.universe, agg_valve, 'centroid')
#      50 ax0.plot([defuzz_val, defuzz_val], [0, 1], 'r', linewidth=1.5, label='Defuzzified Output')
#      51 ax0.legend()
#
# AttributeError: module 'skfuzzy.control' has no attribute 'defuzz'
