# %%
# Import necessary libraries
import zipfile
from google.colab import files

# Upload the zip file
uploaded = files.upload()

# Get the filename from the uploaded files
zip_filename = next(iter(uploaded))

# Unzip the file
with zipfile.ZipFile(zip_filename, 'r') as zip_ref:
    zip_ref.extractall('datas')

# List the contents of the unzipped directory
import os
print("Contents of the unzipped directory:")
print(os.listdir('datas'))
# Out:
#      <input type="file" id="files-eede0ab2-58ee-4e53-8d69-7bec19713f54" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eede0ab2-58ee-4e53-8d69-7bec19713f54">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set the seaborn style
sns.set(style='dark', palette='deep', font='sans-serif', font_scale=1.2, color_codes=True, rc={"figure.figsize": (10, 6)})

# Directory containing the CSV files
directory = 'datas'

# List all CSV files in the directory
csv_files = [file for file in os.listdir(directory) if file.endswith('.csv')]

# Loop through each CSV file and generate plots and display the head
for csv_file in csv_files:
    file_path = os.path.join(directory, csv_file)
    print(f"Head of {csv_file}:")
    df = pd.read_csv(file_path)
    display(df.head())
    print("\n" + "="*100 + "\n")

    print(f"Visualizing {csv_file}:")
    df = pd.read_csv(file_path)

    # Ensure only the 'tweet' and 'emotion' columns are used
    df = df[['tweet', 'emotion']]

    # Bar plot
    plt.figure(figsize=(10, 5))
    sns.countplot(y='emotion', data=df, order=df['emotion'].value_counts().index)
    plt.title(f'Bar Plot for {csv_file}')
    plt.xlabel('Count')
    plt.ylabel('Emotion')
    plt.gcf().set_facecolor('gray')

    plt.show()

    print("\n" + "="*100 + "\n")
# Out:
# Head of surprise.csv:
#                                                tweet  replyCount  \
# 0   نمیدونم چی قبول شدی ولی اییییییوللللللل فاااا...           0
# 1      اصلا نگران نباش همه رو یاد میگیری روزای او...           0
# 2    برای اثبات حرفت سند داری؟\nیا یه چک بزنن بهت...           0
# 3      فوقش یکی دوروز گیر باشن روت...\nب اینم اهم...           1
# 4  میخوای معنی #رفیق و بدونی؟!\nکار دیشب آقا کریم...           0
#
#    retweetCount  likeCount  quoteCount                           hashtags  \
# 0             0          0           0                        ['monstax']
# 1             0          0           0                       ['엑소', '디오']
# 2             0          0           0       ['حلقه_خاتمی', 'حلقه_هاشمی']
# 3             1          0           0  ['DONT_FIGHT_THE_FEELING', 'EXO']
# 4             3         13           0                           ['رفیق']
#
#            sourceLabel   emotion
# 0  Twitter for Android  surprise
# 1  Twitter for Android  surprise
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Define the path where my CSV files are located
path = 'datas'

# List of CSV files
files = ['anger.csv', 'disgust.csv', 'fear.csv', 'joy.csv', 'sad.csv', 'surprise.csv']

# Initialize an empty DataFrame
df = pd.DataFrame()

# Load and concatenate all CSV files
for file in files:
    file_path = os.path.join(path, file)
    temp_df = pd.read_csv(file_path)
    df = pd.concat([df, temp_df], ignore_index=True)

# Display the first few rows of the DataFrame
print(df.head())

# Plot the distribution of classes
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='emotion',hue='emotion', palette='viridis')
plt.title('Distribution of Emotions in the Dataset')
plt.xlabel('Emotion')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
#                                                tweet  replyCount  \
# 0  دیشب خواب دیدم بمبی چیزی زدن نورش خیلی خیره کن...           0
# 1  تبر زدی بر ریشه‌اَم، جوانه رویید جایِ زخم\nران...           0
# 2  پدر سوخته ای که بابام بهم میگه دو معنی داره که...           1
# 3  با خود مواجه شوید و اخم نکنید. اقتدار در نگاه ...           0
# 4  مدح تو را در شادی و در غم نوشتند\nبا این همه ا...           4
#
#    retweetCount  likeCount  quoteCount         hashtags          sourceLabel  \
# 0             3          2           0        ['No2IR']      Twitter Web App
# 1             0          8           0      ['سين_کاف']  Twitter for Android
# 2             0         11           0   ['پدر_ایرانی']  Twitter for Android
# 3             0          1           0  ['جذبه', 'اخم']   Twitter for iPhone
# 4             6         36           0     ['نبأ_عظیم']      Twitter Web App
#
#   emotion
# 0   anger
# 1   anger
# 2   anger
# 3   anger
# 4   anger

# %%
# !pip install spellchecker
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 31.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for spellchecker: filename=spellchecker-0.4-py3-none-any.whl size=3966500 sha256=d1b8796cbad8736bb8bdf18434bc0b83ad3cd7a3500a5b38869fccf27c6db093
#   Stored in directory: /root/.cache/pip/wheels/6c/90/c3/eac248d8755b2a7343487a2087b4b29ad98f388c3c8c69c286
# ...
#   Created wheel for inexactsearch: filename=inexactsearch-1.0.2-py3-none-any.whl size=7123 sha256=c894a0559c4469493b38714e7e02e78a991b3ce970f3713ea796b0b4e3c6e8e3
#   Stored in directory: /root/.cache/pip/wheels/63/19/2c/5e9f447f2533d457a1167c3e553f235e232b8a639e3f5fafab
# ...
#   Created wheel for silpa_common: filename=silpa_common-0.3-py3-none-any.whl size=8466 sha256=5cb5e25c0bfbd6237910e7feee1aae6256eb7ed9b3f87dbb723d562d94971246
# ...

# %%
# !pip install emoji
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 4.4 MB/s eta 0:00:00
# ...

# %%
# !pip install nltk

# %%
# !pip install pandas nltk emoji matplotlib seaborn

# %%
import pandas as pd
import re
import os
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from emoji import demojize
import matplotlib.pyplot as plt
import seaborn as sns
import re, collections

# Ensure you have the necessary NLTK resources
import nltk
nltk.download('stopwords')

# Custom Persian stopwords list (example, you may need to refine this list)
persian_stopwords = set([
    'و', 'در', 'به', 'از', 'که', 'این', 'را', 'با', 'برای', 'است', 'آن', 'هم',
    'یک', 'تا', 'می', 'بر', 'بود', 'شد', 'نیز', 'وی', 'ها', 'ما', 'خود', 'من'
])

# Function to delete HTML tags and URLs
def delete_html_urls(text):
    text = re.sub(r'<.*?>', '', text)  # delete HTML tags
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)  # delete URLs
    return text

# Function to delete repetitive characters
def delete_repetitive_characters(text):
    text = re.sub(r'(.)\1+', r'\1', text)  # Replace multiple occurrences of a character with one
    return text

# Function to delete stopwords
def delete_stopwords(text):
    words = text.split()
    words = [word for word in words if word not in persian_stopwords]
    return ' '.join(words)

# Function to replace emojis with their textual equivalents
def replace_emojis(text):
    return demojize(text)

# Initialize stemmer
stemmer = SnowballStemmer("english")

# Function to apply stemming
def apply_stemming(text):
    words = text.split()
    words = [stemmer.stem(word) for word in words]
    return ' '.join(words)
# Normalizer function

# Function to correct spelling (stub function, needs implementation)
def normalizer(word):
    word = word.replace('ي', 'ی')
    word = word.replace('ك', 'ک')
    word = word.replace('ٔ', '')
    return word

# Train function for spelling correction
def train(features):
    model = collections.defaultdict(lambda: 1)
    for f in features:
        model[f] += 1
    return model

# Apply preprocessing steps
df['tweet'] = df['tweet'].apply(delete_html_urls)
df['tweet'] = df['tweet'].apply(delete_repetitive_characters)
df['tweet'] = df['tweet'].apply(replace_emojis)
df['tweet'] = df['tweet'].apply(delete_stopwords)
df['tweet'] = df['tweet'].apply(apply_stemming)
df['tweet'] = df['tweet'].apply(correct_spelling)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Sample tweets for demonstration
sample_tweets = [
    "این یک <b>تست</b> است http://example.com",  # Example for HTML and URLs
    "خووووووب",  # Example for repetitive characters
    "من به مدرسه می‌روم",  # Example for stopwords
    "من 😊 خوشحالم",  # Example for emojis
    "کتاب‌ها خوانده شده‌اند"  # Example for stemming
]

print('This is sample tweets before preprocessing:\n')
print(sample_tweets)

# Apply preprocessing steps to sample tweets
preprocessed_tweets = []
for tweet in sample_tweets:
    tweet = delete_html_urls(tweet)
    tweet = delete_repetitive_characters(tweet)
    tweet = replace_emojis(tweet)
    tweet = delete_stopwords(tweet)
    tweet = apply_stemming(tweet)
    tweet = correct_spelling(tweet)
    preprocessed_tweets.append(tweet)

print('\nThis is sample tweets after preprocessing:\n')
print(preprocessed_tweets)
# Out:
# This is sample tweets before preprocessing:
#
# ['این یک <b>تست</b> است http://example.com', 'خووووووب', 'من به مدرسه می\u200cروم', 'من 😊 خوشحالم', 'کتاب\u200cها خوانده شده\u200cاند']
#
# This is sample tweets after preprocessing:
#
# ['تست', 'خوب', 'مدرسه می\u200cروم', ':smiling_face_with_smiling_eyes: خوشحالم', 'کتاب\u200cها خوانده شده\u200cاند']

# %%
# Apply preprocessing steps to the actual dataset
df['tweet'] = df['tweet'].apply(delete_html_urls)
df['tweet'] = df['tweet'].apply(delete_repetitive_characters)
df['tweet'] = df['tweet'].apply(replace_emojis)
df['tweet'] = df['tweet'].apply(delete_stopwords)
df['tweet'] = df['tweet'].apply(apply_stemming)
df['tweet'] = df['tweet'].apply(correct_spelling)

# Display the first few rows of the DataFrame to verify the preprocessing
print(df.head())

# Plot the distribution of classes
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='emotion',hue='emotion', palette='viridis')
plt.title('Distribution of Emotions in the Dataset')
plt.xlabel('Emotion')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
#                                                tweet emotion
# 0  دلم چیزی ویران شده، چیزی نمی‌دانم چیست اضطراب ...    fear
# 1  هرگز نباید پی حذف اضطراب باشیم. تشویش همواره د...    fear
# 2  احساسات افراد لطمه نمی زند، دفاع لطمه زند. احس...    fear
# 3  اتفاقاً اونا اضطراب ترس قهرمانی #پرسپولیس خواب...    fear
# 4  :red_heart:در دلم چیزی ویران شده، چیزی نمی‌دان...    fear

# %%
# Apply preprocessing steps to the entire dataset
df['tweet'] = df['tweet'].apply(delete_html_urls)
df['tweet'] = df['tweet'].apply(delete_repetitive_characters)
df['tweet'] = df['tweet'].apply(replace_emojis)
df['tweet'] = df['tweet'].apply(delete_stopwords)
df['tweet'] = df['tweet'].apply(apply_stemming)
df['tweet'] = df['tweet'].apply(correct_spelling)

# Display the first few rows of the DataFrame to verify the preprocessing
print(df.head())

# Plot the distribution of classes
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='emotion', palette='viridis')
plt.title('Distribution of Emotions in the Dataset')
plt.xlabel('Emotion')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# Before correcting spelling: استاد #جواد_خیابانی یه نیمه‌ی کامل برناردو سیلوا گفت برونو فرناندز! شاید براتون سؤال باشه برونو فرناندز چی می‌گفت؟ اونم می‌گفت برونو فرناندز! یعنی براش عجیب نبود دوتا بازیکن دو چهره متفاوت دو شماره متفاوت تو زمین اسم جفتشون یکیه؟
# After correcting spelling: استاد #جواد_خیابانی یه نیمه‌ی کامل برناردو سیلوا گفت برونو فرناندز! شاید براتون سؤال باشه برونو فرناندز چی می‌گفت؟ اونم می‌گفت برونو فرناندز! یعنی براش عجیب نبود دوتا بازیکن دو چهره متفاوت دو شماره متفاوت تو زمین اسم جفتشون یکیه؟
# Before correcting spelling: ولی دارم یه نکته عجیب فکر میکنم؛ اینکه #رئیسی زیر ۵۰ درصد رای میاورد باطله دوم میشد! میکشید دور دوم بین رئیسی باطله باطله کسب اکثریت آرا بعنوان ریس جمهور انتخاب میشد:face_with_tears_of_joy::victory_hand: #طنز #سلام_بر_ابراهیم #باطله
# ...

# %%
from transformers import AutoTokenizer

# Convert pre-processed text data into numbers with ParsBERT tokenizer
tokenizer = AutoTokenizer.from_pretrained("HooshvareLab/bert-base-parsbert-uncased")

def tokenize_text(text):
    return tokenizer(text, return_tensors="pt", padding=True, truncation=True)

# Tokenize the pre-processed tweets
tokenized_tweets = df['tweet'].apply(tokenize_text)

# Display the first few tokenized tweets
for i, tokenized_tweet in enumerate(tokenized_tweets[:5]):
    print(f"Tokenized Tweet {i+1}: {tokenized_tweet}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/434 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.22M [00:00<?, ?B/s]
# ...

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud

# Convert pre-processed text data into numbers with ParsBERT tokenizer
tokenizer = AutoTokenizer.from_pretrained("HooshvareLab/bert-base-parsbert-uncased")

def tokenize_text(text):
    return tokenizer(text, return_tensors="pt", padding=True, truncation=True)

# Tokenize the pre-processed tweets
tokenized_tweets = df['tweet'].apply(tokenize_text)

# Flatten the tokenized tweets into a single list of tokens
all_tokens = [token for tokenized_tweet in tokenized_tweets for token in tokenized_tweet['input_ids'].squeeze().tolist()]

# Create a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(collections.Counter(all_tokens))

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Tokenized Tweets')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-8196748bb7c2> in <cell line: 16>()
#      14
#      15 # Create a word cloud
# ---> 16 wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(collections.Counter(all_tokens))
#      17
#      18 # Display the word cloud
#
# /usr/local/lib/python3.10/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
# ...

# %%
import pandas as pd
import re
import os
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from emoji import demojize
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from transformers import AutoTokenizer
from wordcloud import WordCloud

# Ensure you have the necessary NLTK resources
import nltk
nltk.download('stopwords')

# Custom Persian stopwords list (example, you may need to refine this list)
persian_stopwords = set([
    'و', 'در', 'به', 'از', 'که', 'این', 'را', 'با', 'برای', 'است', 'آن', 'هم',
    'یک', 'تا', 'می', 'بر', 'بود', 'شد', 'نیز', 'وی', 'ها', 'ما', 'خود', 'من'
])

# Function to delete HTML tags and URLs
def delete_html_urls(text):
    text = re.sub(r'<.*?>', '', text)  # delete HTML tags
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)  # delete URLs
    return text

# Function to delete repetitive characters
def delete_repetitive_characters(text):
    text = re.sub(r'(.)\1+', r'\1', text)  # Replace multiple occurrences of a character with one
    return text

# Function to delete stopwords
def delete_stopwords(text):
    words = text.split()
    words = [word for word in words if word not in persian_stopwords]
    return ' '.join(words)

# Function to replace emojis with their textual equivalents
def replace_emojis(text):
    return demojize(text)

# Initialize stemmer
stemmer = SnowballStemmer("english")

# Function to apply stemming
def apply_stemming(text):
    words = text.split()
    words = [stemmer.stem(word) for word in words]
    return ' '.join(words)

# Normalizer function
def normalizer(word):
    word = word.replace('ي', 'ی')
    word = word.replace('ك', 'ک')
    word = word.replace('ٔ', '')
    return word

# Train function for spelling correction
def train(features):
    model = collections.defaultdict(lambda: 1)
    for f in features:
        model[f] += 1
    return model

# Function to correct spelling (stub function, needs implementation)
def correct_spelling(text):
    # Implement a spelling correction function or use a library/tool for this
    return text

# Load the dataset
path = 'datas'  # Replace with your actual path
files = ['anger.csv', 'disgust.csv', 'fear.csv', 'joy.csv', 'sad.csv', 'surprise.csv']
df = pd.DataFrame()

for file in files:
    file_path = os.path.join(path, file)
    temp_df = pd.read_csv(file_path, usecols=['tweet', 'emotion'])
    df = pd.concat([df, temp_df], ignore_index=True)

# Apply preprocessing steps to the entire dataset
df['tweet'] = df['tweet'].apply(delete_html_urls)
df['tweet'] = df['tweet'].apply(delete_repetitive_characters)
df['tweet'] = df['tweet'].apply(replace_emojis)
df['tweet'] = df['tweet'].apply(delete_stopwords)
df['tweet'] = df['tweet'].apply(apply_stemming)
df['tweet'] = df['tweet'].apply(correct_spelling)

# Display the first few rows of the DataFrame to verify the preprocessing
print(df.head())

# Plot the distribution of classes
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='emotion', palette='viridis')
plt.title('Distribution of Emotions in the Dataset')
plt.xlabel('Emotion')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# Convert pre-processed text data into numbers with ParsBERT tokenizer
tokenizer = AutoTokenizer.from_pretrained("HooshvareLab/bert-base-parsbert-uncased")

def tokenize_text(text):
    return tokenizer(text, return_tensors="pt", padding=True, truncation=True)

# Tokenize the pre-processed tweets
tokenized_tweets = df['tweet'].apply(tokenize_text)

# Flatten the tokenized tweets into a single list of token IDs
all_token_ids = [token for tokenized_tweet in tokenized_tweets for token in tokenized_tweet['input_ids'].squeeze().tolist()]

# Convert token IDs to token strings
all_tokens = tokenizer.convert_ids_to_tokens(all_token_ids)

# Create a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(collections.Counter(all_tokens))

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Tokenized Tweets')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                tweet emotion
# 0  دیشب خواب دیدم بمبی چیزی زدن نورش خیلی خیره کن...   anger
# 1  تبر زدی ریشه‌اَم، جوانه روید جایِ زخم راندی مر...   anger
# 2  پدر سوخته ای بابام بهم میگه دو معنی داره خودم ...   anger
# 3  مواجه شوید اخم نکنید. اقتدار نگاه ات نه چشمانت...   anger
# 4  مدح تو شادی غم نوشتند همه اما برایت کم نوشتند ...   anger
# <ipython-input-42-f5244b68e48a>:95: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='emotion', palette='viridis')
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the CountVectorizer
vectorizer = CountVectorizer()

# Fit and transform the preprocessed tweets to create the DTM
dtm = vectorizer.fit_transform(df['tweet'])

# Convert the DTM to an array
dtm_array = dtm.toarray()

# Print the shape of the DTM
print(f"DTM shape: {dtm_array.shape}")

# %%
from transformers import AutoModel
import torch

# Load the ParsBERT model
model = AutoModel.from_pretrained("HooshvareLab/bert-base-parsbert-uncased")

# Function to get ParsBERT embeddings
def get_parsbert_embeddings(text):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)
    with torch.no_grad():
        outputs = model(**inputs)
    # Use the mean of the last hidden state as the embedding
    embeddings = outputs.last_hidden_state.mean(dim=1)
    return embeddings.squeeze().numpy()

# Apply the function to get embeddings for each tweet
embeddings = df['tweet'].apply(get_parsbert_embeddings)

# Convert the embeddings to a numpy array
embeddings_array = np.vstack(embeddings)

# Print the shape of the embeddings array
print(f"Embeddings shape: {embeddings_array.shape}")

# %%
import numpy as np

# Combine BOW features and ParsBERT embeddings
combined_features = np.hstack([dtm_array, embeddings_array])

# Print the shape of the combined features
print(f"Combined features shape: {combined_features.shape}")
